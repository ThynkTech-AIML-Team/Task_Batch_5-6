# %%
# !pip install sumy
# Out:
# ...
#   Using cached sumy-0.12.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached breadability-0.1.20.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached docopt_ng-0.9.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached lxml_html_clean-0.4.3-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached pycountry-26.2.16-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

# %%
import nltk
nltk.download('punkt_tab')

parser = PlaintextParser.from_string(text, Tokenizer("english"))
summarizer = LsaSummarizer()

# %%
text = """
Artificial Intelligence is transforming industries around the world.
It is being used in healthcare to detect diseases early and improve
patient outcomes. In finance, AI helps detect fraud and automate
trading systems. In education, AI supports personalized learning.
Machine learning and deep learning are major branches of AI that
allow systems to learn from data. As technology advances, AI will
become even more powerful and widely used. However, ethical concerns
and responsible usage must be considered carefully.
"""

# %%
summary = summarizer(parser.document, 3)

print("SUMMARY:\n")
for sentence in summary:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 summary = summarizer(parser.document, 3)
#       3 print("SUMMARY:\n")
#       4 for sentence in summary:
#
# NameError: name 'summarizer' is not defined
