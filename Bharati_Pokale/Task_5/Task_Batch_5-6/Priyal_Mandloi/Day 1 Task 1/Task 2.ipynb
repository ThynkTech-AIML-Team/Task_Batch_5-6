# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
paragraph = "Natural Language Processing is a key area of AI. It helps computers understand human language."

sentences = sent_tokenize(paragraph)
tokens = word_tokenize(paragraph)

print("Paragraph:")
print(paragraph)

print("\nSentences:")
print(sentences)

print("\nTokens:")
print(tokens)

print("\nCounts:")
print("Number of Sentences:", len(sentences))
print("Number of Tokens:", len(tokens))
print("Number of Paragraphs: 1")
# Out:
# Paragraph:
# Natural Language Processing is a key area of AI. It helps computers understand human language.
#
# Sentences:
# ['Natural Language Processing is a key area of AI.', 'It helps computers understand human language.']
#
# Tokens:
# ['Natural', 'Language', 'Processing', 'is', 'a', 'key', 'area', 'of', 'AI', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.']
#
# Counts:
# Number of Sentences: 2
# Number of Tokens: 17
# Number of Paragraphs: 1
