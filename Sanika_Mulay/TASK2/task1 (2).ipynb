# %%
# !pip install scikit-learn
# !pip install nltk
# !pip install gensim
# !pip install pyLDAvis
# !pip install bertopic
# !pip install umap-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in c:\users\admin\appdata\roaming\python\python313\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from gensim) (2.3.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in c:\programdata\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyLDAvis in c:\users\admin\appdata\roaming\python\python313\site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis) (2.3.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis) (1.16.3)
# Requirement already satisfied: pandas>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis) (2.3.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis) (1.5.2)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis) (3.1.6)
# Requirement already satisfied: numexpr in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis) (2.14.1)
# Requirement already satisfied: funcy in c:\users\admin\appdata\roaming\python\python313\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis) (1.7.2)
# Requirement already satisfied: gensim in c:\users\admin\appdata\roaming\python\python313\site-packages (from pyLDAvis) (4.4.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis) (80.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from gensim->pyLDAvis) (7.5.0)
# Requirement already satisfied: wrapt in c:\programdata\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim->pyLDAvis) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->pyLDAvis) (3.0.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bertopic in c:\users\admin\appdata\roaming\python\python313\site-packages (0.17.4)
# Requirement already satisfied: hdbscan>=0.8.29 in c:\users\admin\appdata\roaming\python\python313\site-packages (from bertopic) (0.8.41)
# Requirement already satisfied: umap-learn>=0.5.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from bertopic) (0.5.11)
# Requirement already satisfied: numpy>=1.20.0 in c:\programdata\anaconda3\lib\site-packages (from bertopic) (2.3.5)
# Requirement already satisfied: pandas>=1.1.5 in c:\programdata\anaconda3\lib\site-packages (from bertopic) (2.3.3)
# Requirement already satisfied: plotly>=4.7.0 in c:\programdata\anaconda3\lib\site-packages (from bertopic) (6.3.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\programdata\anaconda3\lib\site-packages (from bertopic) (1.7.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from bertopic) (5.2.3)
# Requirement already satisfied: tqdm>=4.41.1 in c:\programdata\anaconda3\lib\site-packages (from bertopic) (4.67.1)
# Requirement already satisfied: llvmlite>0.36.0 in c:\programdata\anaconda3\lib\site-packages (from bertopic) (0.45.1)
# Requirement already satisfied: scipy>=1.0 in c:\programdata\anaconda3\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.16.3)
# Requirement already satisfied: joblib>=1.0 in c:\programdata\anaconda3\lib\site-packages (from hdbscan>=0.8.29->bertopic) (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\programdata\anaconda3\lib\site-packages (from plotly>=4.7.0->bertopic) (2.7.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from plotly>=4.7.0->bertopic) (25.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0->bertopic) (3.5.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from sentence-transformers>=0.4.1->bertopic) (5.2.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from sentence-transformers>=0.4.1->bertopic) (1.4.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from sentence-transformers>=0.4.1->bertopic) (2.10.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.15.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2025.9.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\admin\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\admin\appdata\roaming\python\python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.7.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (0.28.1)
# Requirement already satisfied: shellingham in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.5.4)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.5)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.41.1->bertopic) (0.4.6)
# Requirement already satisfied: numba>=0.51.2 in c:\programdata\anaconda3\lib\site-packages (from umap-learn>=0.5.0->bertopic) (0.62.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\admin\appdata\roaming\python\python313\site-packages (from umap-learn>=0.5.0->bertopic) (0.6.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: typer>=0.24.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in c:\programdata\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (8.2.1)
# Requirement already satisfied: rich>=12.3.0 in c:\programdata\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: umap-learn in c:\users\admin\appdata\roaming\python\python313\site-packages (0.5.11)
# Requirement already satisfied: numpy>=1.23 in c:\programdata\anaconda3\lib\site-packages (from umap-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from umap-learn) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.6 in c:\programdata\anaconda3\lib\site-packages (from umap-learn) (1.7.2)
# Requirement already satisfied: numba>=0.51.2 in c:\programdata\anaconda3\lib\site-packages (from umap-learn) (0.62.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\admin\appdata\roaming\python\python313\site-packages (from umap-learn) (0.6.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\programdata\anaconda3\lib\site-packages (from numba>=0.51.2->umap-learn) (0.45.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.6->umap-learn) (3.5.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->umap-learn) (0.4.6)

# %%
import re
import nltk
import pickle
import numpy as np
import pyLDAvis
pyLDAvis.enable_notebook()

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from gensim.models import CoherenceModel
import gensim.corpora as corpora
from bertopic import BERTopic

# %%
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset = fetch_20newsgroups(remove=('headers', 'footers', 'quotes'))
documents = dataset.data
print("Total documents:", len(documents))
# Out:
# Total documents: 11314

# %%
def preprocess(text):
    text = text.lower()
    text = re.sub(r'\W+', ' ', text)
    tokens = word_tokenize(text)
    tokens = [w for w in tokens if w not in stop_words and len(w) > 3]
    return " ".join(tokens)

cleaned_docs = [preprocess(doc) for doc in documents]
print("Sample preprocessed doc:\n", cleaned_docs[0][:200])
# Out:
# Sample preprocessed doc:
#  wondering anyone could enlighten door sports looked late early called bricklin doors really small addition front bumper separate rest body know anyone tellme model name engine specs years production m

# %%
# For LDA → CountVectorizer
count_vectorizer = CountVectorizer(max_df=0.95, min_df=2)
dtm = count_vectorizer.fit_transform(cleaned_docs)

# For NMF → TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2)
tfidf = tfidf_vectorizer.fit_transform(cleaned_docs)

# %%
n_topics = 10

lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda.fit(dtm)
print("LDA Perplexity:", lda.perplexity(dtm))

# Document-topic distribution for pyLDAvis
doc_topic_dists = lda.transform(dtm)
# Out:
# LDA Perplexity: 5336.914279211712

# %%
nmf = NMF(n_components=n_topics, random_state=42)
nmf.fit(tfidf)
# Out:
# NMF(n_components=10, random_state=42)

# %%
texts = [doc.split() for doc in cleaned_docs]
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# Extract top words per topic
lda_topics = []
for topic in lda.components_:
    words = [count_vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-11:-1]]
    lda_topics.append(words)

coherence_model_lda = CoherenceModel(topics=lda_topics, texts=texts, dictionary=dictionary, coherence='c_v')
print("LDA Coherence Score:", coherence_model_lda.get_coherence())
# Out:
# LDA Coherence Score: 0.5757592723222666

# %%
lda_vis = pyLDAvis.prepare(
    topic_term_dists=lda.components_,
    doc_topic_dists=doc_topic_dists,
    vocab=count_vectorizer.get_feature_names_out(),
    doc_lengths=dtm.sum(axis=1).A1,
    term_frequency=dtm.sum(axis=0).A1
)
lda_vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2     -0.051702  0.102157       1        1  17.301407
# 7      0.233497  0.029087       2        1  15.130741
# 8     -0.042120  0.148272       3        1  14.299305
# 0     -0.048243 -0.103652       4        1   9.843872
# 1      0.131449 -0.013004       5        1   8.218584
# 6     -0.107442 -0.220397       6        1   7.636064
# 4      0.136181 -0.015566       7        1   7.522263
# 3     -0.127606 -0.048356       8        1   7.470510
# 9     -0.166714  0.150290       9        1   7.334479
# 5      0.042699 -0.028830      10        1   5.242776, topic_info=          Term          Freq         Total Category  logprob  loglift
# 31674  windows  1.695214e+08  1.695214e+08  Default  30.0000  30.0000
# 21700   people  5.026567e+08  5.026567e+08  Default  29.0000  29.0000
# 10038    drive  1.463557e+08  1.463557e+08  Default  28.0000  28.0000
# 29070    think  4.018324e+08  4.018324e+08  Default  27.0000  27.0000
# 5824      card  1.089817e+08  1.089817e+08  Default  26.0000  26.0000
# ...        ...           ...           ...      ...      ...      ...
# 19914     need  5.699579e+06  1.894588e+08  Topic10   4.7645  11.0480
# 31852     work  5.500952e+06  1.959394e+08  Topic10   4.7290  10.9789
# 11128     even  5.466071e+06  2.701137e+08  Topic10   4.7227  10.6515
# 31904    would  5.736567e+06  7.358492e+08  Topic10   4.7710   9.6976
# 26538    since  5.215063e+06  1.651028e+08  Topic10   4.6757  11.0968
#
# [815 rows x 6 columns], token_table=       Topic      Freq   Term
# term
# 26         1  0.015004   00pm
# 26         2  0.013122   00pm
# 26         3  0.012401   00pm
# 26         4  0.008537   00pm
# 26         5  0.007128   00pm
# ...      ...       ...    ...
# 32418      6  0.066337  years
# 32418      7  0.015959  years
# 32418      8  0.036105  years
# 32418      9  0.010868  years
# 32418     10  0.010474  years
#
# [6810 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 8, 9, 1, 2, 7, 5, 4, 10, 6])

# %%
# Save models
with open("lda_model.pkl", "wb") as f:
    pickle.dump(lda, f)

with open("nmf_model.pkl", "wb") as f:
    pickle.dump(nmf, f)

# Save LDA visualization as HTML
pyLDAvis.save_html(lda_vis, "lda_dashboard.html")
print("Models and visualization saved!")
# Out:
# Models and visualization saved!

# %%
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(cleaned_docs)
topic_model.visualize_topics()
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
